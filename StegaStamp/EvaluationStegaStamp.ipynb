# %%
# !cd StegaStamp && \
/data/xwt/miniconda3/envs/legacy_tf_torch/bin/python encode_image.py \
  saved_models/stegastamp_pretrained \
  --image test_img.jpg  \
  --save_dir out \
  --secret THUSIGS
# Out:
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2021-05-21 18:29:00.557144: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-05-21 18:29:00.699458: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2021-05-21 18:29:00.708081: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x5555591b1e50 executing computations on platform Host. Devices:
# 2021-05-21 18:29:00.708156: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-05-21 18:29:00.839389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:18:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:29:00.934955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 1 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:3b:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:29:01.027281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 2 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:86:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:29:01.147084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 3 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:af:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:29:01.147489: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0, 1, 2, 3
# 2021-05-21 18:29:01.151178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-21 18:29:01.151196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0 1 2 3
# 2021-05-21 18:29:01.151204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N N N N
# 2021-05-21 18:29:01.151211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 1:   N N N N
# 2021-05-21 18:29:01.151217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 2:   N N N N
# 2021-05-21 18:29:01.151222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 3:   N N N N
# 2021-05-21 18:29:01.151420: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10312 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:18:00.0, compute capability: 7.5)
# 2021-05-21 18:29:01.151734: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10312 MB memory) -> physical GPU (device: 1, name: GeForce RTX 2080 Ti, pci bus id: 0000:3b:00.0, compute capability: 7.5)
# 2021-05-21 18:29:01.151923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10312 MB memory) -> physical GPU (device: 2, name: GeForce RTX 2080 Ti, pci bus id: 0000:86:00.0, compute capability: 7.5)
# 2021-05-21 18:29:01.152094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10312 MB memory) -> physical GPU (device: 3, name: GeForce RTX 2080 Ti, pci bus id: 0000:af:00.0, compute capability: 7.5)
# 2021-05-21 18:29:01.169150: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55555b763ba0 executing computations on platform CUDA. Devices:
# 2021-05-21 18:29:01.169177: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 18:29:01.169185: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 18:29:01.169192: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 18:29:01.169199: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): GeForce RTX 2080 Ti, Compute Capability 7.5
# WARNING:tensorflow:From encode_image.py:34: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# WARNING:tensorflow:From /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-05-21 18:29:06.415583: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.9.2 locally

# %%
from PIL import Image,ImageOps
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show_result(filename, hidden_img, residual_img):
    # show these three img encoded
    # sess.run(tf.global_variables_initializer())
    
    fig = plt.figure()
    
    ax = fig.add_subplot(131)
    ax.set_title('source image')
    src_img = mpimg.imread(filename)
    ax.imshow(src_img)
    
    ax = fig.add_subplot(132)
    ax.set_title('hidden image')
    hid_img = mpimg.imread(hidden_img)
    ax.imshow(hid_img)
    
    ax = fig.add_subplot(133)
    ax.set_title('residual image')
    res_img = mpimg.imread(residual_img)
    ax.imshow(res_img)

    
filename, hidden_img, residual_img = [
    'StegaStamp/test_img.jpg', 'StegaStamp/out/test_img_hidden.png',
    'StegaStamp/out/test_img_residual.png']
show_result(filename, hidden_img, residual_img)

# %%
# !cd StegaStamp && \
/data/xwt/miniconda3/envs/legacy_tf_torch/bin/python decode_image.py \
  saved_models/stegastamp_pretrained \
  --image out/test_img_hidden.png
# Out:
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2021-05-21 18:32:31.612119: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-05-21 18:32:31.639467: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2021-05-21 18:32:31.641343: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x5555591aedd0 executing computations on platform Host. Devices:
# 2021-05-21 18:32:31.641384: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-05-21 18:32:31.752642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:18:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:32:31.846174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 1 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:3b:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:32:31.935058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 2 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:86:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:32:32.044927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 3 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:af:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 18:32:32.045291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0, 1, 2, 3
# 2021-05-21 18:32:32.048876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-21 18:32:32.048896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0 1 2 3
# 2021-05-21 18:32:32.048904: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N N N N
# 2021-05-21 18:32:32.048910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 1:   N N N N
# 2021-05-21 18:32:32.048916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 2:   N N N N
# 2021-05-21 18:32:32.048922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 3:   N N N N
# 2021-05-21 18:32:32.049052: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10312 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:18:00.0, compute capability: 7.5)
# 2021-05-21 18:32:32.049336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10312 MB memory) -> physical GPU (device: 1, name: GeForce RTX 2080 Ti, pci bus id: 0000:3b:00.0, compute capability: 7.5)
# 2021-05-21 18:32:32.049517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10312 MB memory) -> physical GPU (device: 2, name: GeForce RTX 2080 Ti, pci bus id: 0000:86:00.0, compute capability: 7.5)
# 2021-05-21 18:32:32.049715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10312 MB memory) -> physical GPU (device: 3, name: GeForce RTX 2080 Ti, pci bus id: 0000:af:00.0, compute capability: 7.5)
# 2021-05-21 18:32:32.051620: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55555b760ae0 executing computations on platform CUDA. Devices:
# 2021-05-21 18:32:32.051644: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 18:32:32.051651: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 18:32:32.051658: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 18:32:32.051665: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): GeForce RTX 2080 Ti, Compute Capability 7.5
# WARNING:tensorflow:From decode_image.py:32: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# WARNING:tensorflow:From /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-05-21 18:32:33.120409: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.9.2 locally
# out/test_img_hidden.png THUSIGS

# %%
# !cd StegaStamp && \
/data/xwt/miniconda3/envs/legacy_tf_torch/bin/python detector.py \
  --detector_model detector_models/stegastamp_detector \
  --decoder_model saved_models/stegastamp_pretrained \
  --video test_vid.mp4 \
  --save_video test_vid_detected.mp4
# Out:
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2021-05-21 19:10:11.205058: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-05-21 19:10:11.212676: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2021-05-21 19:10:11.214514: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x555559230c30 executing computations on platform Host. Devices:
# 2021-05-21 19:10:11.214547: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-05-21 19:10:11.324786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:18:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 19:10:11.418374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 1 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:3b:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 19:10:11.514067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 2 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:86:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 19:10:11.631453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 3 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:af:00.0
# totalMemory: 10.76GiB freeMemory: 10.60GiB
# 2021-05-21 19:10:11.631819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0, 1, 2, 3
# 2021-05-21 19:10:11.635421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-21 19:10:11.635438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0 1 2 3
# 2021-05-21 19:10:11.635446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N N N N
# 2021-05-21 19:10:11.635452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 1:   N N N N
# 2021-05-21 19:10:11.635457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 2:   N N N N
# 2021-05-21 19:10:11.635463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 3:   N N N N
# 2021-05-21 19:10:11.635592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10312 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:18:00.0, compute capability: 7.5)
# 2021-05-21 19:10:11.635870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10312 MB memory) -> physical GPU (device: 1, name: GeForce RTX 2080 Ti, pci bus id: 0000:3b:00.0, compute capability: 7.5)
# 2021-05-21 19:10:11.636063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10312 MB memory) -> physical GPU (device: 2, name: GeForce RTX 2080 Ti, pci bus id: 0000:86:00.0, compute capability: 7.5)
# 2021-05-21 19:10:11.636238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10312 MB memory) -> physical GPU (device: 3, name: GeForce RTX 2080 Ti, pci bus id: 0000:af:00.0, compute capability: 7.5)
# 2021-05-21 19:10:11.638173: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55555b7e2ca0 executing computations on platform CUDA. Devices:
# 2021-05-21 19:10:11.638198: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 19:10:11.638206: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 19:10:11.638212: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2021-05-21 19:10:11.638218: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): GeForce RTX 2080 Ti, Compute Capability 7.5
# WARNING:tensorflow:From detector.py:56: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# WARNING:tensorflow:From /data/xwt/miniconda3/envs/legacy_tf_torch/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-05-21 19:10:13.327213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0, 1, 2, 3
# 2021-05-21 19:10:13.327624: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-21 19:10:13.327637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0 1 2 3
# 2021-05-21 19:10:13.327643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N N N N
# 2021-05-21 19:10:13.327649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 1:   N N N N
# 2021-05-21 19:10:13.327655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 2:   N N N N
# 2021-05-21 19:10:13.327661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 3:   N N N N
# 2021-05-21 19:10:13.327781: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10312 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:18:00.0, compute capability: 7.5)
# 2021-05-21 19:10:13.327973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10312 MB memory) -> physical GPU (device: 1, name: GeForce RTX 2080 Ti, pci bus id: 0000:3b:00.0, compute capability: 7.5)
# 2021-05-21 19:10:13.328126: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10312 MB memory) -> physical GPU (device: 2, name: GeForce RTX 2080 Ti, pci bus id: 0000:86:00.0, compute capability: 7.5)
# 2021-05-21 19:10:13.328276: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10312 MB memory) -> physical GPU (device: 3, name: GeForce RTX 2080 Ti, pci bus id: 0000:af:00.0, compute capability: 7.5)
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 2021-05-21 19:10:16.880309: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.9.2 locally
# Num bits corrected:  2
# Num bits corrected:  0
# Num bits corrected:  3
# Num bits corrected:  4
# Num bits corrected:  5
# Num bits corrected:  2
